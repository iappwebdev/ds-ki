# %% [markdown]
# # Testseite für neue Features
#
# Diese Seite dient als Ort für das Testen neuer Features und sollte nicht in der Live-Version der Seite auftauchen.
#
# ## Tooltips
# ```{warning}
# :name: hinweis-tooltips
# 1. Die Tooltips funktionieren manchmal beim Entwickeln mit `make develop` nicht für Links auf andere Seiten im Buch. Hier muss ein `make clean` erfolgen, damit die Links wieder funktionieren. Hat aber keine Auswirkung auf die Live-Version, da diese ja nur einmal gebaut wird und dann nicht mehr verändert wird.
# Alternativ für das Testen der Tooltip die Seite mit `make build` neu bauen und manuell öffnen ohne Live-Server.
# 2. Die Referenzen der Tooltips können unterschiedlich angebeben werden. Es ist jedoch ratsam, immer den gewünschten Text und den Namen der Referenz anzugeben. Also statt ``{term}`Aktivierungsfunktion` `` lieber ``{term}`Aktivierungsfunktion <Aktivierungsfunktion>` ``. So ist man auf der sicheren Seite, wenn sie der Name eines Dokuments oder einer Referenz ändern sollte.
#
# ```
#
# ```{seealso}
# - [sphinx-tippy Beispiel](https://sphinx-tippy.readthedocs.io/en/latest/) (https://github.com/sphinx-extensions2/sphinx-tippy)
# - [teachbooks-sphinx-tippy Beispiel](https://teachbooks.io/TeachBooks-sphinx-tippy-Example/main/) (https://github.com/TeachBooks/teachbooks-sphinx-tippy)
# ```
#
# **Beispiele:**
#
# - Link zu ipynb-Seite: [](live_code)
# - Link zu ipynb-Seite mit eigenem Text: [Live code](live_code)
# - Link zu ipynb-Seite in Unterordner: [](ki/knearestneighbor)
# - Link zu ipynb-Seite in Unterordner mit eigenem Text: [k-Nächste-Nachbarn-Algorithmus](ki/knearestneighbor)
# - Link zu ipynb-Seite mit {doc}: {doc}`live_code`
# - Link zu ipynb-Seite mit {doc} und eigenem Text: {doc}`Live code <live_code>`
# - Link zu ipynb-Seite mit {doc} in Unterordner: {doc}`ki/knearestneighbor`
# - Link zu ipynb-Seite mit {doc} in Unterordner und eigenem Text: {doc}`k-Nächste-Nachbarn-Algorithmus <ki/knearestneighbor>`
# - Link zu Glossar: {term}`Aktivierungsfunktion`
# - Link zu Glossar mit eigenem Text: {term}`siehe Backpropagation <Backpropagation>`
# - Link zu Admonition: {ref}`hinweis-tooltips` (schneit nicht zu funktionieren)
# - Link zu Admonition mit eigenem Text: {ref}`Hinweis zu Tooltips <hinweis-tooltips>`
# - Link zu Beispiel-Abschnitt mit ``{ref}``: {ref}`Beispiel-Abschnitt <beispiel-abschnitt>`
# - Link zu Beispiel-Abschnitt mit ``[]()``: [Beispiel-Abschnitt](#beispiel-abschnitt)
# - Link zu englischen Wikipedia: [Tooltip](https://en.wikipedia.org/wiki/Tooltip) \[deutsches Wiki leider nicht unterstützt\]
#
# ## Block attributes
#
# ```{seealso}
# https://myst-parser.readthedocs.io/en/latest/syntax/optional.html#block-attributes
# ```
#
# {#mypara .bg-warning}
# Das ist ein ganzer Paragraf als Warnung hinterlegt.
#
# Referenz zum vorigen {ref}`Paragraphen <mypara>` mit Tooltip.
#
# ## Definition lists and glossaries
# ```{seealso}
# https://myst-parser.readthedocs.io/en/latest/syntax/typography.html#syntax-glossaries
# ```
#
# Automatisches Formatieren für Glossar-Einträge:
#
# {.glossary}
# Term 1
# : Definition
#
# Term 2
# : Longer definition
#
#   With multiple paragraphs
#
# Referenz zu den vorigen Definitionen {term}`Term 1` und {term}`Term 2` mit Tooltip.
#
#
# ## Inline attributes
#
# ```{seealso}
# https://myst-parser.readthedocs.io/en/latest/syntax/optional.html#inline-attributes
# ```
# Hier kommt ein [Text mit Warnung]{.bg-warning} in einem Textabschnitt
#
# (beispiel-abschnitt)=
# ## Beispiel-Abschnitt zum verlinken
# Diesen Abschnitt kann man auch verlinken, indem mal einen Verweisschlüssel vorher
# setzt mit ``(...)=``.
# Achtung: damit die Verlinkung als Link mit 🔗 erscheint, muss der Link mit
# als Rolle mit ``{ref}... <...>`` statt als Cross Referenz mit ``[...](...)`` gesetzt werden.
